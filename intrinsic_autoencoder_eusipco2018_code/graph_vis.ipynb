# %%
from graph_vis import visualize_graph
visualize_graph('./ssd_mobilenet_0.1_FACES_300x300_FINETUNED_70000.pb')
# Out:
#             <iframe seamless style="width:1000px;height:1000px;border:0" srcdoc="
#             <script>
#               function load() {
# ...
